# %% [markdown]
# <a href="https://colab.research.google.com/github/abdulrehmanustad/data-analayst/blob/main/RUNS_DATA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

rundata=pd.read_csv('ICC Test Bat 3001.csv').head(100)
#TOP 10 RUNSCORER IN TEST HISTORY
top_10=rundata.loc[:,['Player','Runs']]
top_10['Runs']=pd.to_numeric(top_10['Runs'])
top_10=top_10.sort_values(by='Runs',ascending=False).head(10).reset_index(drop=True)
print(top_10)
plt.figure(figsize=(10,6))
sns.barplot(x='Player',y='Runs',data=top_10,palette='viridis')

plt.xlabel('Player')

plt.ylabel('Runs')
plt.title('Top 10 Run Scorers')
plt.xticks(rotation=45)
plt.show()
# Out:
#                   Player   Runs
# 0   SR Tendulkar (INDIA)  15921
# 1       RT Ponting (AUS)  13378
# 2     JH Kallis (ICC/SA)  13289
# 3   R Dravid (ICC/INDIA)  13288
# 4          AN Cook (ENG)  12472
# 5     KC Sangakkara (SL)  12400
# 6       BC Lara (ICC/WI)  11953
# 7     S Chanderpaul (WI)  11867
# 8  DPMD Jayawardene (SL)  11814
# 9        AR Border (AUS)  11174
# /tmp/ipykernel_17446/339944959.py:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Player',y='Runs',data=top_10,palette='viridis')

# %%
# MOST 100 BY A INDIVIDUAL
most_100=rundata.loc[:,['Player','100']]
most_100['100']=pd.to_numeric(most_100['100'])
most_100=most_100.sort_values(by='100',ascending=False).head(10)
print(most_100)

plt.figure(figsize=(10,6))
sns.barplot(x='Player',y='100',data=most_100,palette='viridis')
plt.xlabel('Player')
plt.ylabel('100s')
plt.title('Top 10 Scorers with 100s')
plt.xticks(rotation=45)
plt.show()
# Out:
#                    Player  100
# 0    SR Tendulkar (INDIA)   51
# 2      JH Kallis (ICC/SA)   45
# 1        RT Ponting (AUS)   41
# 5      KC Sangakkara (SL)   38
# 3    R Dravid (ICC/INDIA)   36
# 6        BC Lara (ICC/WI)   34
# 11    SM Gavaskar (INDIA)   34
# 8   DPMD Jayawardene (SL)   34
# 12      Younis Khan (PAK)   34
# 4           AN Cook (ENG)   33
# /tmp/ipykernel_17446/1473705376.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Player',y='100',data=most_100,palette='viridis')

# %%
# MOST 50 BY A INDIVIDUAL
most_50=rundata.loc[:,['Player','50']]
most_50['50']=pd.to_numeric(most_50['50'])
most_50=most_50.sort_values(by='50',ascending=False).head(10)
print(most_50)

plt.figure(figsize=(10,6))
sns.barplot(x='Player',y='50',data=most_50,color='red')
plt.xlabel('Player')
plt.ylabel('50s')
plt.title('Top 10 Scorers with 50s')
plt.xticks(rotation=45)
plt.show()
# Out:
#                   Player  50
# 0   SR Tendulkar (INDIA)  68
# 7     S Chanderpaul (WI)  66
# 9        AR Border (AUS)  63
# 3   R Dravid (ICC/INDIA)  63
# 1       RT Ponting (AUS)  62
# 2     JH Kallis (ICC/SA)  58
# 4          AN Cook (ENG)  57
# 18    VVS Laxman (INDIA)  56
# 5     KC Sangakkara (SL)  52
# 10        SR Waugh (AUS)  50

# %%
# HIGHEST INDIVIDUAL SCORE BY A PLAYER
high_score=rundata.loc[:,['Player','HS']]
high_score['HS']=pd.to_numeric(high_score['HS'], errors='coerce')
high_score=high_score.sort_values(by='HS',ascending=False).head(10)
print(high_score)
plt.figure(figsize=(10,6))
sns.barplot(x='Player',y='HS',data=high_score,color='green')
plt.xlabel('Player')
plt.ylabel('Highest Score')
plt.title('Top 10 Highest Scores')
plt.xticks(rotation=45)
plt.show()
# Out:
#                       Player     HS
# 21           ML Hayden (AUS)  380.0
# 8      DPMD Jayawardene (SL)  374.0
# 54            L Hutton (ENG)  364.0
# 53        ST Jayasuriya (SL)  340.0
# 52          DG Bradman (AUS)  334.0
# 43             CH Gayle (WI)  333.0
# 15            GA Gooch (ENG)  333.0
# 17  Inzamam-ul-Haq (ICC/PAK)  329.0
# 5         KC Sangakkara (SL)  319.0
# 22      V Sehwag (ICC/INDIA)  319.0
